# %% [markdown]
# Contoh aturan penulisan blok diagram pada python

# %%
# blok percabangan if
if username == 'Mahasiswa':
    print("Selamat Datang Admin") #
    print("Silahkan ambil tempat duduk")

# blok percabangan for
for i in range(10):
    print i

# %% [markdown]
# Contoh penulisan sintak python (antara variabel penulisan harus dibedakan)

# %%
judul = "Belajar Dasar-dasar Python"
Judul = "Belajar Membuat Program Python"

# %% [markdown]
# Contoh penulisan case

# %%
## Snake Case digunakan pada:
module_name, package_name, method_name, function_name, , global_var_name, instance_var_name, function_parameter_name, local_var_name.

## CamelCase digunakan Pada:
ClassName, ExceptionName
 
## ALL CAPS digunakan Pada:
GLOBAL_CONSTANT_NAME
