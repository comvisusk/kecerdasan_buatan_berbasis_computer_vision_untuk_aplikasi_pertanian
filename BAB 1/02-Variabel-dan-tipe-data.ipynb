# %% [markdown]
# #**VARIABEL**

# %% [markdown]
# Format variabel pada python

# %%
variabel_ku = "Nilai kuliah"
variabel2 = 20

# %%
print (variabel_ku)
print (variabel2)

# %% [markdown]
# #**TIPE DATA**

# %% [markdown]
# Tipe data number (integer, float)

# %%
harga = 12000 #tipe int
berat = 23.12 #float
jarak = 3e3 #float 3000.0, huruf e artinya eksponen 10

# %% [markdown]
# Tipe Data String (Teks)

# %%
nama = "Ivan"
jenis_kelamin = 'L'
alamat = "jalan kemang dalam"

# %% [markdown]
# Tipe data boolean

# %%
bergerak = True
nyala = 1 #sebenarnya tipenya int, tapi bisa juga menjadi bool

# %% [markdown]
# ## Contoh kode periksa tipe data

# %%
a = True
print(a, "is of", type(a))
# Out:
# True is of <class 'bool'>

# %%
i = -7
print(i, "is of", type(i))
# Out:
# -7 is of <class 'int'>

# %%
x = 12.7893
print(x, "is of", type(x))
# Out:
# 12.7893 is of <class 'float'>

# %%
s = "Workshop"
print(s, "is of", type(s))
# Out:
# Workshop is of <class 'str'>

# %%
z = None
print(z, "is of", type(z))
# Out:
# None is of <class 'NoneType'>

# %% [markdown]
# # **TYPECASTING CAST**

# %% [markdown]
# ## Contoh pengkonversian secara implisit

# %%
a = 10 / 2
print(type(a))

b = 1 / 2
print(type(b))
# Out:
# <class 'float'>
# <class 'float'>

# %%
kata = 'Jeruk ' * 5

print(kata)
print(type(kata))
# Out:
# Jeruk Jeruk Jeruk Jeruk Jeruk
# <class 'str'>

# %% [markdown]
# ## Contoh pengkonversian secara eksplisit

# %%
int(8.21)
# Out:
# 8

# %%
float(9)
# Out:
# 9.0

# %%
str(1)
# Out:
# '1'

# %%
int("213")
# Out:
# 213

# %% [markdown]
# ## Contoh pengkonversian secara eksplisit yang error

# %%
int("saya mau makan")
