# %% [markdown]
# # Divide Data to MinTemp & MaxTemp

# %%
X = dataset['MinTemp'].values.reshape(-1,1)
y = dataset['MaxTemp'].values.reshape(-1,1)

# %% [markdown]
# # Divide Dataset to Training & Testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Training Data used LinearRegression()

# %%
regressor = LinearRegression() 
regressor.fit(X_train, y_train) #training the a
# Out:
# LinearRegression()

# %% [markdown]
# Lihat nilai slope

# %%
print(regressor.coef_)
# Out:
# [[0.92033997]]

# %% [markdown]
# Lihat nilai intercept

# %%
print(regressor.intercept_)
# Out:
# [10.66185201]

# %% [markdown]
# Atau used this code to get coeffisien

# %%
X_aug = np.concatenate([X_train, np.ones_like(X_train)], axis=1)

XTX = np.matmul(X_aug.transpose(), X_aug)
XTY = np.matmul(X_aug.transpose(), y_train)
a = np.matmul(np.linalg.inv(XTX), XTY)

print(a)
# Out:
# [[ 0.92033997]
#  [10.66185201]]
