# %% [markdown]
# # Features dan Target pada Dataset

# %% [markdown]
# x = features, y = target

# %%
x=data.drop('Lint Yield (Pounds/Harvested Acre)',axis=1)
y=data['Lint Yield (Pounds/Harvested Acre)']

# %% [markdown]
# # Pengecekan Korelasi Antar Features

# %% [markdown]
# Mengecek nilai feature yang memiliki nilai korelasi tinggi

# %%
from scipy.stats import pearsonr
 
cor1, _ = pearsonr(data['State'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Year'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Nitrogen (%)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Nitrogen (Pounds/Acre)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Phosphorous (%)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Phosphorous (Pounds/Acre)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Potash (%)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Potash (Pounds/Acre)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Area Planted (acres)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
cor1, _ = pearsonr(data['Harvested Area (acres)'], data['Lint Yield (Pounds/Harvested Acre)'])
print('Pearsons correlation: %.3f' % cor1)
 
sns.heatmap(data.corr(),annot=True,cmap='terrain',linewidth=5)
fig=plt.gcf() 
fig.set_size_inches(15,10)

# %% [markdown]
# # Pembuatan model

# %%
from sklearn import ensemble
yield_predict = ensemble.GradientBoostingRegressor(
   n_estimators = 100,
   max_depth = 5,
   min_samples_split = 2,
   learning_rate = 0.1,
   loss = 'squared_error'
)
