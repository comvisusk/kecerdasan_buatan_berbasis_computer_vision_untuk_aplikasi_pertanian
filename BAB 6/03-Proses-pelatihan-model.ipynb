# %% [markdown]
# # Pembagian Dataset

# %% [markdown]
# Pembagian dataset menggunakan semua feature yang ada

# %%
'''No feature drop, 80% for Training and 20% for Testing'''
from sklearn.model_selection import train_test_split
 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)

# %% [markdown]
# Pembagian data tidak menggunakan data Potash

# %%
'''With feature drop, 80% for Training and 20% for Testing'''
from sklearn.model_selection import train_test_split
 
x_train,x_test,y_train,y_test=train_test_split(
   x.drop('Potash (Pounds/Acre)', axis=1),y,test_size=0.2)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)

# %% [markdown]
# # Proses Training

# %%
yield_predict.fit(x_train, y_train)
